# %% [markdown]
# <a href="https://colab.research.google.com/github/LikhithaMaanyam/PRODIGY_DS_01/blob/main/Prodigy_task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Sample data: Creating a DataFrame with ages and genders
data = {
    'Age': [23, 45, 31, 22, 34, 29, 43, 35, 50, 27, 22, 33, 41, 29, 40],
    'Gender': ['Female', 'Male', 'Female', 'Female', 'Male',
               'Male', 'Female', 'Male', 'Female', 'Female',
               'Male', 'Female', 'Male', 'Male', 'Female']
}

df = pd.DataFrame(data)

# Set the style of seaborn
sns.set(style='whitegrid')

# Create a figure
plt.figure(figsize=(10, 6))

# Create a histogram for age distribution, separated by gender
sns.histplot(data=df, x='Age', hue='Gender', multiple='stack', bins=10)

# Adding titles and labels
plt.title('Age Distribution by Gender', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Count', fontsize=14)

# Show the plot
plt.show()
